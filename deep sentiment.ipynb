# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import re
from sklearn.model_selection import train_test_split
import nltk
from nltk.tokenize import TweetTokenizer
import string
import contractions

# %% [markdown]
# ### Step 1 - load the data and take a look

# %%
col_names = ['label', 'id', 'date', 'flag', 'user', 'text']
df = pd.read_csv('bert_model/sentiment140/training.csv', encoding='latin-1', names=col_names)
df = df[['text', 'label']]
print(df.head(2))
print("\nThere are {} tweets in total.\n".format(len(df)))
print("There are {} positve tweets".format(np.sum(df["label"] == 4)))
print("There are {} neural tweets".format(np.sum(df["label"] == 2)))
print("There are {} negative tweets".format(np.sum(df["label"] == 0)))
# Out:
#                                                 text  label
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...      0
# 1  is upset that he can't update his Facebook by ...      0
#
# There are 1600000 tweets in total.
#
# There are 800000 positve tweets
# There are 0 neural tweets
# There are 800000 negative tweets

# %% [markdown]
# ### Step 2 - Generate train, val, test data set

# %%
# test = pd.read_csv('data/test.csv', encoding='latin-1', names=col_names)
# X_test = test["text"].values.tolist()
# y_test = test["label"].values.tolist()

# train, val = train_test_split(df, test_size=0.1)
# X_train = train["text"].values.tolist()
# y_train = train["label"].values.tolist()

# X_val = val["text"].values.tolist()
# y_val = val["label"].values.tolist()

# print("There are {} train set".format(len(X_train)))
# print("There are {} validation set".format(len(X_val)))
# print("There are {} test set".format(len(X_test)))

# %%
def remove_mention(text):
    return re.sub('@[^\s]+','',text)

text = "@David hi"
remove_mention(text)
# Out:
# ' hi'

# %%
def remove_html(text):
    soup = BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    return souped

text = "&amp; I like it"
remove_html(text)
# Out:
# '& I like it'

# %%
def remove_url(text):
    return re.sub(r'http\S+', '', text)

text = "Check this video http://bit.ly/IMXUM"
remove_url(text)
# Out:
# 'Check this video '

# %%
def remove_hashtag(text):
    return re.sub(r'#\w*', '', text)

text = "#trumpisidiot hahah"
remove_hashtag(text)
# Out:
# ' hahah'

# %%
def remove_punctuation(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

text = 'string with "punctuation" inside of it! Does this work? I hope so.'
remove_punctuation(text)
# Out:
# 'string with punctuation inside of it Does this work I hope so'

# %%
def fix_contractions(text):
    return contractions.fix(text)

text = "I can't help you!"
fix_contractions(text)
# Out:
# 'I can not help you!'

# %%
def preprocess(text):
    text = remove_html(text)
    text = remove_mention(text)
    text = remove_url(text)
    text = remove_hashtag(text)
    text = fix_contractions(text)

    words = TweetTokenizer().tokenize(text)
    words = [word.lower() for word in words]
    # Remove punctuation
    words = [remove_punctuation(word) for word in words]
    # Remove words that contain numeric values
    words = [word for word in words if word.isalpha()]
    
    return " ".join(words)

text = """
boy's cars
I can't help you. #Fucker. 
Check this out http://shit_url
Lebron..sh*t was hilarious...LMAO!!!
"""
preprocess(text)
# Out:
# 'boys cars i can not help you check this out lebron sh t was hilarious lmao'

# %%
index = 0
max_length = 0
for i, row in df.iterrows():
    if index % 1000 == 0:
        print("Finished processing {} training data".format(index))
    index += 1
    text = df.at[i,'text']
    text = preprocess(text)
    
    length = len(text.split())
    if length > max_length:
        max_length = length
        
    df.at[i,'text'] = text
# Out:
# Finished processing 0 training data
# Finished processing 1000 training data
# Finished processing 2000 training data
# Finished processing 3000 training data
# Finished processing 4000 training data
# Finished processing 5000 training data
# Finished processing 6000 training data
# Finished processing 7000 training data
# Finished processing 8000 training data
# Finished processing 9000 training data
# Finished processing 10000 training data
# Finished processing 11000 training data
# Finished processing 12000 training data
# Finished processing 13000 training data
# Finished processing 14000 training data
# Finished processing 15000 training data
# Finished processing 16000 training data
# Finished processing 17000 training data
# Finished processing 18000 training data
# Finished processing 19000 training data
# Finished processing 20000 training data
# Finished processing 21000 training data
# Finished processing 22000 training data
# Finished processing 23000 training data
# Finished processing 24000 training data
# Finished processing 25000 training data
# Finished processing 26000 training data
# Finished processing 27000 training data
# Finished processing 28000 training data
# Finished processing 29000 training data
# Finished processing 30000 training data
# Finished processing 31000 training data
# Finished processing 32000 training data
# Finished processing 33000 training data
# Finished processing 34000 training data
# Finished processing 35000 training data
# Finished processing 36000 training data
# Finished processing 37000 training data
# Finished processing 38000 training data
# Finished processing 39000 training data
# Finished processing 40000 training data
# Finished processing 41000 training data
# Finished processing 42000 training data
# Finished processing 43000 training data
# Finished processing 44000 training data
# Finished processing 45000 training data
# Finished processing 46000 training data
# Finished processing 47000 training data
# Finished processing 48000 training data
# Finished processing 49000 training data
# Finished processing 50000 training data
# Finished processing 51000 training data
# Finished processing 52000 training data
# Finished processing 53000 training data
# Finished processing 54000 training data
# Finished processing 55000 training data
# Finished processing 56000 training data
# Finished processing 57000 training data
# Finished processing 58000 training data
# Finished processing 59000 training data
# Finished processing 60000 training data
# Finished processing 61000 training data
# Finished processing 62000 training data
# Finished processing 63000 training data
# Finished processing 64000 training data
# Finished processing 65000 training data
# Finished processing 66000 training data
# Finished processing 67000 training data
# Finished processing 68000 training data
# Finished processing 69000 training data
# Finished processing 70000 training data
# Finished processing 71000 training data
# Finished processing 72000 training data
# Finished processing 73000 training data
# Finished processing 74000 training data
# Finished processing 75000 training data
# Finished processing 76000 training data
# Finished processing 77000 training data
# Finished processing 78000 training data
# Finished processing 79000 training data
# Finished processing 80000 training data
# Finished processing 81000 training data
# Finished processing 82000 training data
# Finished processing 83000 training data
# Finished processing 84000 training data
# Finished processing 85000 training data
# Finished processing 86000 training data
# Finished processing 87000 training data
# Finished processing 88000 training data
# Finished processing 89000 training data
# Finished processing 90000 training data
# Finished processing 91000 training data
# Finished processing 92000 training data
# Finished processing 93000 training data
# Finished processing 94000 training data
# Finished processing 95000 training data
# Finished processing 96000 training data
# Finished processing 97000 training data
# Finished processing 98000 training data
# Finished processing 99000 training data
# Finished processing 100000 training data
# Finished processing 101000 training data
# Finished processing 102000 training data
# Finished processing 103000 training data
# Finished processing 104000 training data
# Finished processing 105000 training data
# Finished processing 106000 training data
# Finished processing 107000 training data
# Finished processing 108000 training data
# Finished processing 109000 training data
# Finished processing 110000 training data
# Finished processing 111000 training data
# Finished processing 112000 training data
# Finished processing 113000 training data
# Finished processing 114000 training data
# Finished processing 115000 training data
# Finished processing 116000 training data
# Finished processing 117000 training data
# Finished processing 118000 training data
# Finished processing 119000 training data
# Finished processing 120000 training data
# Finished processing 121000 training data
# Finished processing 122000 training data
# Finished processing 123000 training data
# Finished processing 124000 training data
# Finished processing 125000 training data
# Finished processing 126000 training data
# Finished processing 127000 training data
# Finished processing 128000 training data
# Finished processing 129000 training data
# Finished processing 130000 training data
# Finished processing 131000 training data
# Finished processing 132000 training data
# Finished processing 133000 training data
# Finished processing 134000 training data
# Finished processing 135000 training data
# Finished processing 136000 training data
# Finished processing 137000 training data
# Finished processing 138000 training data
# Finished processing 139000 training data
# Finished processing 140000 training data
# Finished processing 141000 training data
# Finished processing 142000 training data
# Finished processing 143000 training data
# Finished processing 144000 training data
# Finished processing 145000 training data
# Finished processing 146000 training data
# Finished processing 147000 training data
# Finished processing 148000 training data
# Finished processing 149000 training data
# Finished processing 150000 training data
# Finished processing 151000 training data
# Finished processing 152000 training data
# Finished processing 153000 training data
# Finished processing 154000 training data
# Finished processing 155000 training data
# Finished processing 156000 training data
# Finished processing 157000 training data
# Finished processing 158000 training data
# Finished processing 159000 training data
# Finished processing 160000 training data
# Finished processing 161000 training data
# Finished processing 162000 training data
# Finished processing 163000 training data
# Finished processing 164000 training data
# Finished processing 165000 training data
# Finished processing 166000 training data
# Finished processing 167000 training data
# Finished processing 168000 training data
# Finished processing 169000 training data
# Finished processing 170000 training data
# Finished processing 171000 training data
# Finished processing 172000 training data
# Finished processing 173000 training data
# Finished processing 174000 training data
# Finished processing 175000 training data
# Finished processing 176000 training data
# Finished processing 177000 training data
# Finished processing 178000 training data
# Finished processing 179000 training data
# Finished processing 180000 training data
# Finished processing 181000 training data
# Finished processing 182000 training data
# Finished processing 183000 training data
# Finished processing 184000 training data
# Finished processing 185000 training data
# Finished processing 186000 training data
# Finished processing 187000 training data
# Finished processing 188000 training data
# Finished processing 189000 training data
# Finished processing 190000 training data
# Finished processing 191000 training data
# Finished processing 192000 training data
# Finished processing 193000 training data
# Finished processing 194000 training data
# Finished processing 195000 training data
# Finished processing 196000 training data
# Finished processing 197000 training data
# Finished processing 198000 training data
# Finished processing 199000 training data
# Finished processing 200000 training data
# Finished processing 201000 training data
# Finished processing 202000 training data
# Finished processing 203000 training data
# Finished processing 204000 training data
# Finished processing 205000 training data
# Finished processing 206000 training data
# Finished processing 207000 training data
# Finished processing 208000 training data
# Finished processing 209000 training data
# Finished processing 210000 training data
# Finished processing 211000 training data
# Finished processing 212000 training data
# Finished processing 213000 training data
# Finished processing 214000 training data
# Finished processing 215000 training data
# Finished processing 216000 training data
# Finished processing 217000 training data
# Finished processing 218000 training data
# Finished processing 219000 training data
# Finished processing 220000 training data
# Finished processing 221000 training data
# Finished processing 222000 training data
# Finished processing 223000 training data
# Finished processing 224000 training data
# Finished processing 225000 training data
# Finished processing 226000 training data
# Finished processing 227000 training data
# Finished processing 228000 training data
# Finished processing 229000 training data
# Finished processing 230000 training data
# Finished processing 231000 training data
# Finished processing 232000 training data
# Finished processing 233000 training data
# Finished processing 234000 training data
# Finished processing 235000 training data
# Finished processing 236000 training data
# Finished processing 237000 training data
# Finished processing 238000 training data
# Finished processing 239000 training data
# Finished processing 240000 training data
# Finished processing 241000 training data
# Finished processing 242000 training data
# Finished processing 243000 training data
# Finished processing 244000 training data
# Finished processing 245000 training data
# Finished processing 246000 training data
# Finished processing 247000 training data
# Finished processing 248000 training data
# Finished processing 249000 training data
# Finished processing 250000 training data
# Finished processing 251000 training data
# Finished processing 252000 training data
# Finished processing 253000 training data
# Finished processing 254000 training data
# Finished processing 255000 training data
# Finished processing 256000 training data
# Finished processing 257000 training data
# Finished processing 258000 training data
# Finished processing 259000 training data
# Finished processing 260000 training data
# Finished processing 261000 training data
# Finished processing 262000 training data
# Finished processing 263000 training data
# Finished processing 264000 training data
# Finished processing 265000 training data
# Finished processing 266000 training data
# Finished processing 267000 training data
# Finished processing 268000 training data
# Finished processing 269000 training data
# Finished processing 270000 training data
# Finished processing 271000 training data
# Finished processing 272000 training data
# Finished processing 273000 training data
# Finished processing 274000 training data
# Finished processing 275000 training data
# Finished processing 276000 training data
# Finished processing 277000 training data
# Finished processing 278000 training data
# Finished processing 279000 training data
# Finished processing 280000 training data
# Finished processing 281000 training data
# Finished processing 282000 training data
# Finished processing 283000 training data
# Finished processing 284000 training data
# Finished processing 285000 training data
# Finished processing 286000 training data
# Finished processing 287000 training data
# Finished processing 288000 training data
# Finished processing 289000 training data
# Finished processing 290000 training data
# Finished processing 291000 training data
# Finished processing 292000 training data
# Finished processing 293000 training data
# Finished processing 294000 training data
# Finished processing 295000 training data
# Finished processing 296000 training data
# Finished processing 297000 training data
# Finished processing 298000 training data
# Finished processing 299000 training data
# Finished processing 300000 training data
# Finished processing 301000 training data
# Finished processing 302000 training data
# Finished processing 303000 training data
# Finished processing 304000 training data
# Finished processing 305000 training data
# Finished processing 306000 training data
# Finished processing 307000 training data
# Finished processing 308000 training data
# Finished processing 309000 training data
# Finished processing 310000 training data
# Finished processing 311000 training data
# Finished processing 312000 training data
# Finished processing 313000 training data
# Finished processing 314000 training data
# Finished processing 315000 training data
# Finished processing 316000 training data
# Finished processing 317000 training data
# Finished processing 318000 training data
# Finished processing 319000 training data
# Finished processing 320000 training data
# Finished processing 321000 training data
# Finished processing 322000 training data
# Finished processing 323000 training data
# Finished processing 324000 training data
# Finished processing 325000 training data
# Finished processing 326000 training data
# Finished processing 327000 training data
# Finished processing 328000 training data
# Finished processing 329000 training data
# Finished processing 330000 training data
# Finished processing 331000 training data
# Finished processing 332000 training data
# Finished processing 333000 training data
# Finished processing 334000 training data
# Finished processing 335000 training data
# Finished processing 336000 training data
# Finished processing 337000 training data
# Finished processing 338000 training data
# Finished processing 339000 training data
# Finished processing 340000 training data
# Finished processing 341000 training data
# Finished processing 342000 training data
# Finished processing 343000 training data
# Finished processing 344000 training data
# Finished processing 345000 training data
# Finished processing 346000 training data
# Finished processing 347000 training data
# Finished processing 348000 training data
# Finished processing 349000 training data
# Finished processing 350000 training data
# Finished processing 351000 training data
# Finished processing 352000 training data
# Finished processing 353000 training data
# Finished processing 354000 training data
# Finished processing 355000 training data
# Finished processing 356000 training data
# Finished processing 357000 training data
# Finished processing 358000 training data
# Finished processing 359000 training data
# Finished processing 360000 training data
# Finished processing 361000 training data
# Finished processing 362000 training data
# Finished processing 363000 training data
# Finished processing 364000 training data
# Finished processing 365000 training data
# Finished processing 366000 training data
# Finished processing 367000 training data
# Finished processing 368000 training data
# Finished processing 369000 training data
# Finished processing 370000 training data
# Finished processing 371000 training data
# Finished processing 372000 training data
# Finished processing 373000 training data
# Finished processing 374000 training data
# Finished processing 375000 training data
# Finished processing 376000 training data
# Finished processing 377000 training data
# Finished processing 378000 training data
# Finished processing 379000 training data
# Finished processing 380000 training data
# Finished processing 381000 training data
# Finished processing 382000 training data
# Finished processing 383000 training data
# Finished processing 384000 training data
# Finished processing 385000 training data
# Finished processing 386000 training data
# Finished processing 387000 training data
# Finished processing 388000 training data
# Finished processing 389000 training data
# Finished processing 390000 training data
# Finished processing 391000 training data
# Finished processing 392000 training data
# Finished processing 393000 training data
# Finished processing 394000 training data
# Finished processing 395000 training data
# Finished processing 396000 training data
# Finished processing 397000 training data
# Finished processing 398000 training data
# Finished processing 399000 training data
# Finished processing 400000 training data
# Finished processing 401000 training data
# Finished processing 402000 training data
# Finished processing 403000 training data
# Finished processing 404000 training data
# Finished processing 405000 training data
# Finished processing 406000 training data
# Finished processing 407000 training data
# Finished processing 408000 training data
# Finished processing 409000 training data
# Finished processing 410000 training data
# Finished processing 411000 training data
# Finished processing 412000 training data
# Finished processing 413000 training data
# Finished processing 414000 training data
# Finished processing 415000 training data
# Finished processing 416000 training data
# Finished processing 417000 training data
# Finished processing 418000 training data
# Finished processing 419000 training data
# Finished processing 420000 training data
# Finished processing 421000 training data
# Finished processing 422000 training data
# Finished processing 423000 training data
# Finished processing 424000 training data
# Finished processing 425000 training data
# Finished processing 426000 training data
# Finished processing 427000 training data
# Finished processing 428000 training data
# Finished processing 429000 training data
# Finished processing 430000 training data
# Finished processing 431000 training data
# Finished processing 432000 training data
# Finished processing 433000 training data
# Finished processing 434000 training data
# Finished processing 435000 training data
# Finished processing 436000 training data
# Finished processing 437000 training data
# Finished processing 438000 training data
# Finished processing 439000 training data
# Finished processing 440000 training data
# Finished processing 441000 training data
# Finished processing 442000 training data
# Finished processing 443000 training data
# Finished processing 444000 training data
# Finished processing 445000 training data
# Finished processing 446000 training data
# Finished processing 447000 training data
# Finished processing 448000 training data
# Finished processing 449000 training data
# Finished processing 450000 training data
# Finished processing 451000 training data
# Finished processing 452000 training data
# Finished processing 453000 training data
# Finished processing 454000 training data
# Finished processing 455000 training data
# Finished processing 456000 training data
# Finished processing 457000 training data
# Finished processing 458000 training data
# Finished processing 459000 training data
# Finished processing 460000 training data
# Finished processing 461000 training data
# Finished processing 462000 training data
# Finished processing 463000 training data
# Finished processing 464000 training data
# Finished processing 465000 training data
# Finished processing 466000 training data
# Finished processing 467000 training data
# Finished processing 468000 training data
# Finished processing 469000 training data
# Finished processing 470000 training data
# Finished processing 471000 training data
# Finished processing 472000 training data
# Finished processing 473000 training data
# Finished processing 474000 training data
# Finished processing 475000 training data
# Finished processing 476000 training data
# Finished processing 477000 training data
# Finished processing 478000 training data
# Finished processing 479000 training data
# Finished processing 480000 training data
# Finished processing 481000 training data
# Finished processing 482000 training data
# Finished processing 483000 training data
# Finished processing 484000 training data
# Finished processing 485000 training data
# Finished processing 486000 training data
# Finished processing 487000 training data
# Finished processing 488000 training data
# Finished processing 489000 training data
# Finished processing 490000 training data
# Finished processing 491000 training data
# Finished processing 492000 training data
# Finished processing 493000 training data
# Finished processing 494000 training data
# Finished processing 495000 training data
# Finished processing 496000 training data
# Finished processing 497000 training data
# Finished processing 498000 training data
# Finished processing 499000 training data
# Finished processing 500000 training data
# Finished processing 501000 training data
# Finished processing 502000 training data
# Finished processing 503000 training data
# Finished processing 504000 training data
# Finished processing 505000 training data
# Finished processing 506000 training data
# Finished processing 507000 training data
# Finished processing 508000 training data
# Finished processing 509000 training data
# Finished processing 510000 training data
# Finished processing 511000 training data
# Finished processing 512000 training data
# Finished processing 513000 training data
# Finished processing 514000 training data
# Finished processing 515000 training data
# Finished processing 516000 training data
# Finished processing 517000 training data
# Finished processing 518000 training data
# Finished processing 519000 training data
# Finished processing 520000 training data
# Finished processing 521000 training data
# Finished processing 522000 training data
# Finished processing 523000 training data
# Finished processing 524000 training data
# Finished processing 525000 training data
# Finished processing 526000 training data
# Finished processing 527000 training data
# Finished processing 528000 training data
# Finished processing 529000 training data
# Finished processing 530000 training data
# Finished processing 531000 training data
# Finished processing 532000 training data
# Finished processing 533000 training data
# Finished processing 534000 training data
# Finished processing 535000 training data
# Finished processing 536000 training data
# Finished processing 537000 training data
# Finished processing 538000 training data
# Finished processing 539000 training data
# Finished processing 540000 training data
# Finished processing 541000 training data
# Finished processing 542000 training data
# Finished processing 543000 training data
# Finished processing 544000 training data
# Finished processing 545000 training data
# Finished processing 546000 training data
# Finished processing 547000 training data
# Finished processing 548000 training data
# Finished processing 549000 training data
# Finished processing 550000 training data
# Finished processing 551000 training data
# Finished processing 552000 training data
# Finished processing 553000 training data
# Finished processing 554000 training data
# Finished processing 555000 training data
# Finished processing 556000 training data
# Finished processing 557000 training data
# Finished processing 558000 training data
# Finished processing 559000 training data
# Finished processing 560000 training data
# Finished processing 561000 training data
# Finished processing 562000 training data
# Finished processing 563000 training data
# Finished processing 564000 training data
# Finished processing 565000 training data
# Finished processing 566000 training data
# Finished processing 567000 training data
# Finished processing 568000 training data
# Finished processing 569000 training data
# Finished processing 570000 training data
# Finished processing 571000 training data
# Finished processing 572000 training data
# Finished processing 573000 training data
# Finished processing 574000 training data
# Finished processing 575000 training data
# Finished processing 576000 training data
# Finished processing 577000 training data
# Finished processing 578000 training data
# Finished processing 579000 training data
# Finished processing 580000 training data
# Finished processing 581000 training data
# Finished processing 582000 training data
# Finished processing 583000 training data
# Finished processing 584000 training data
# Finished processing 585000 training data
# Finished processing 586000 training data
# Finished processing 587000 training data
# Finished processing 588000 training data
# Finished processing 589000 training data
# Finished processing 590000 training data
# Finished processing 591000 training data
# Finished processing 592000 training data
# Finished processing 593000 training data
# Finished processing 594000 training data
# Finished processing 595000 training data
# Finished processing 596000 training data
# Finished processing 597000 training data
# Finished processing 598000 training data
# Finished processing 599000 training data
# Finished processing 600000 training data
# Finished processing 601000 training data
# Finished processing 602000 training data
# Finished processing 603000 training data
# Finished processing 604000 training data
# Finished processing 605000 training data
# Finished processing 606000 training data
# Finished processing 607000 training data
# Finished processing 608000 training data
# Finished processing 609000 training data
# Finished processing 610000 training data
# Finished processing 611000 training data
# Finished processing 612000 training data
# Finished processing 613000 training data
# Finished processing 614000 training data
# Finished processing 615000 training data
# Finished processing 616000 training data
# Finished processing 617000 training data
# Finished processing 618000 training data
# Finished processing 619000 training data
# Finished processing 620000 training data
# Finished processing 621000 training data
# Finished processing 622000 training data
# Finished processing 623000 training data
# Finished processing 624000 training data
# Finished processing 625000 training data
# Finished processing 626000 training data
# Finished processing 627000 training data
# Finished processing 628000 training data
# Finished processing 629000 training data
# Finished processing 630000 training data
# Finished processing 631000 training data
# Finished processing 632000 training data
# Finished processing 633000 training data
# Finished processing 634000 training data
# Finished processing 635000 training data
# Finished processing 636000 training data
# Finished processing 637000 training data
# Finished processing 638000 training data
# Finished processing 639000 training data
# Finished processing 640000 training data
# Finished processing 641000 training data
# Finished processing 642000 training data
# Finished processing 643000 training data
# Finished processing 644000 training data
# Finished processing 645000 training data
# Finished processing 646000 training data
# Finished processing 647000 training data
# Finished processing 648000 training data
# Finished processing 649000 training data
# Finished processing 650000 training data
# Finished processing 651000 training data
# Finished processing 652000 training data
# Finished processing 653000 training data
# Finished processing 654000 training data
# Finished processing 655000 training data
# Finished processing 656000 training data
# Finished processing 657000 training data
# Finished processing 658000 training data
# Finished processing 659000 training data
# Finished processing 660000 training data
# Finished processing 661000 training data
# Finished processing 662000 training data
# Finished processing 663000 training data
# Finished processing 664000 training data
# Finished processing 665000 training data
# Finished processing 666000 training data
# Finished processing 667000 training data
# Finished processing 668000 training data
# Finished processing 669000 training data
# Finished processing 670000 training data
# Finished processing 671000 training data
# Finished processing 672000 training data
# Finished processing 673000 training data
# Finished processing 674000 training data
# Finished processing 675000 training data
# Finished processing 676000 training data
# Finished processing 677000 training data
# Finished processing 678000 training data
# Finished processing 679000 training data
# Finished processing 680000 training data
# Finished processing 681000 training data
# Finished processing 682000 training data
# Finished processing 683000 training data
# Finished processing 684000 training data
# Finished processing 685000 training data
# Finished processing 686000 training data
# Finished processing 687000 training data
# Finished processing 688000 training data
# Finished processing 689000 training data
# Finished processing 690000 training data
# Finished processing 691000 training data
# Finished processing 692000 training data
# Finished processing 693000 training data
# Finished processing 694000 training data
# Finished processing 695000 training data
# Finished processing 696000 training data
# Finished processing 697000 training data
# Finished processing 698000 training data
# Finished processing 699000 training data
# Finished processing 700000 training data
# Finished processing 701000 training data
# Finished processing 702000 training data
# Finished processing 703000 training data
# Finished processing 704000 training data
# Finished processing 705000 training data
# Finished processing 706000 training data
# Finished processing 707000 training data
# Finished processing 708000 training data
# Finished processing 709000 training data
# Finished processing 710000 training data
# Finished processing 711000 training data
# Finished processing 712000 training data
# Finished processing 713000 training data
# Finished processing 714000 training data
# Finished processing 715000 training data
# Finished processing 716000 training data
# Finished processing 717000 training data
# Finished processing 718000 training data
# Finished processing 719000 training data
# Finished processing 720000 training data
# Finished processing 721000 training data
# Finished processing 722000 training data
# Finished processing 723000 training data
# Finished processing 724000 training data
# Finished processing 725000 training data
# Finished processing 726000 training data
# Finished processing 727000 training data
# Finished processing 728000 training data
# Finished processing 729000 training data
# Finished processing 730000 training data
# Finished processing 731000 training data
# Finished processing 732000 training data
# Finished processing 733000 training data
# Finished processing 734000 training data
# Finished processing 735000 training data
# Finished processing 736000 training data
# Finished processing 737000 training data
# Finished processing 738000 training data
# Finished processing 739000 training data
# Finished processing 740000 training data
# Finished processing 741000 training data
# Finished processing 742000 training data
# Finished processing 743000 training data
# Finished processing 744000 training data
# Finished processing 745000 training data
# Finished processing 746000 training data
# Finished processing 747000 training data
# Finished processing 748000 training data
# Finished processing 749000 training data
# Finished processing 750000 training data
# Finished processing 751000 training data
# Finished processing 752000 training data
# Finished processing 753000 training data
# Finished processing 754000 training data
# Finished processing 755000 training data
# Finished processing 756000 training data
# Finished processing 757000 training data
# Finished processing 758000 training data
# Finished processing 759000 training data
# Finished processing 760000 training data
# Finished processing 761000 training data
# Finished processing 762000 training data
# Finished processing 763000 training data
# Finished processing 764000 training data
# Finished processing 765000 training data
# Finished processing 766000 training data
# Finished processing 767000 training data
# Finished processing 768000 training data
# Finished processing 769000 training data
# Finished processing 770000 training data
# Finished processing 771000 training data
# Finished processing 772000 training data
# Finished processing 773000 training data
# Finished processing 774000 training data
# Finished processing 775000 training data
# Finished processing 776000 training data
# Finished processing 777000 training data
# Finished processing 778000 training data
# Finished processing 779000 training data
# Finished processing 780000 training data
# Finished processing 781000 training data
# Finished processing 782000 training data
# Finished processing 783000 training data
# Finished processing 784000 training data
# Finished processing 785000 training data
# Finished processing 786000 training data
# Finished processing 787000 training data
# Finished processing 788000 training data
# Finished processing 789000 training data
# Finished processing 790000 training data
# Finished processing 791000 training data
# Finished processing 792000 training data
# Finished processing 793000 training data
# Finished processing 794000 training data
# Finished processing 795000 training data
# Finished processing 796000 training data
# Finished processing 797000 training data
# Finished processing 798000 training data
# Finished processing 799000 training data
# Finished processing 800000 training data
# Finished processing 801000 training data
# Finished processing 802000 training data
# Finished processing 803000 training data
# Finished processing 804000 training data
# Finished processing 805000 training data
# Finished processing 806000 training data
# Finished processing 807000 training data
# Finished processing 808000 training data
# Finished processing 809000 training data
# Finished processing 810000 training data
# Finished processing 811000 training data
# Finished processing 812000 training data
# Finished processing 813000 training data
# Finished processing 814000 training data
# Finished processing 815000 training data
# Finished processing 816000 training data
# Finished processing 817000 training data
# Finished processing 818000 training data
# Finished processing 819000 training data
# Finished processing 820000 training data
# Finished processing 821000 training data
# Finished processing 822000 training data
# Finished processing 823000 training data
# Finished processing 824000 training data
# Finished processing 825000 training data
# Finished processing 826000 training data
# Finished processing 827000 training data
# Finished processing 828000 training data
# Finished processing 829000 training data
# Finished processing 830000 training data
# Finished processing 831000 training data
# Finished processing 832000 training data
# Finished processing 833000 training data
# Finished processing 834000 training data
# Finished processing 835000 training data
# Finished processing 836000 training data
# Finished processing 837000 training data
# Finished processing 838000 training data
# Finished processing 839000 training data
# Finished processing 840000 training data
# Finished processing 841000 training data
# Finished processing 842000 training data
# Finished processing 843000 training data
# Finished processing 844000 training data
# Finished processing 845000 training data
# Finished processing 846000 training data
# Finished processing 847000 training data
# Finished processing 848000 training data
# Finished processing 849000 training data
# Finished processing 850000 training data
# Finished processing 851000 training data
# Finished processing 852000 training data
# Finished processing 853000 training data
# Finished processing 854000 training data
# Finished processing 855000 training data
# Finished processing 856000 training data
# Finished processing 857000 training data
# Finished processing 858000 training data
# Finished processing 859000 training data
# Finished processing 860000 training data
# Finished processing 861000 training data
# Finished processing 862000 training data
# Finished processing 863000 training data
# Finished processing 864000 training data
# Finished processing 865000 training data
# Finished processing 866000 training data
# Finished processing 867000 training data
# Finished processing 868000 training data
# Finished processing 869000 training data
# Finished processing 870000 training data
# Finished processing 871000 training data
# Finished processing 872000 training data
# Finished processing 873000 training data
# Finished processing 874000 training data
# Finished processing 875000 training data
# Finished processing 876000 training data
# Finished processing 877000 training data
# Finished processing 878000 training data
# Finished processing 879000 training data
# Finished processing 880000 training data
# Finished processing 881000 training data
# Finished processing 882000 training data
# Finished processing 883000 training data
# Finished processing 884000 training data
# Finished processing 885000 training data
# Finished processing 886000 training data
# Finished processing 887000 training data
# Finished processing 888000 training data
# Finished processing 889000 training data
# Finished processing 890000 training data
# Finished processing 891000 training data
# Finished processing 892000 training data
# Finished processing 893000 training data
# Finished processing 894000 training data
# Finished processing 895000 training data
# Finished processing 896000 training data
# Finished processing 897000 training data
# Finished processing 898000 training data
# Finished processing 899000 training data
# Finished processing 900000 training data
# Finished processing 901000 training data
# Finished processing 902000 training data
# Finished processing 903000 training data
# Finished processing 904000 training data
# Finished processing 905000 training data
# Finished processing 906000 training data
# Finished processing 907000 training data
# Finished processing 908000 training data
# Finished processing 909000 training data
# Finished processing 910000 training data
# Finished processing 911000 training data
# Finished processing 912000 training data
# Finished processing 913000 training data
# Finished processing 914000 training data
# Finished processing 915000 training data
# Finished processing 916000 training data
# Finished processing 917000 training data
# Finished processing 918000 training data
# Finished processing 919000 training data
# Finished processing 920000 training data
# Finished processing 921000 training data
# Finished processing 922000 training data
# Finished processing 923000 training data
# Finished processing 924000 training data
# Finished processing 925000 training data
# Finished processing 926000 training data
# Finished processing 927000 training data
# Finished processing 928000 training data
# Finished processing 929000 training data
# Finished processing 930000 training data
# Finished processing 931000 training data
# Finished processing 932000 training data
# Finished processing 933000 training data
# Finished processing 934000 training data
# Finished processing 935000 training data
# Finished processing 936000 training data
# Finished processing 937000 training data
# Finished processing 938000 training data
# Finished processing 939000 training data
# Finished processing 940000 training data
# Finished processing 941000 training data
# Finished processing 942000 training data
# Finished processing 943000 training data
# Finished processing 944000 training data
# Finished processing 945000 training data
# Finished processing 946000 training data
# Finished processing 947000 training data
# Finished processing 948000 training data
# Finished processing 949000 training data
# Finished processing 950000 training data
# Finished processing 951000 training data
# Finished processing 952000 training data
# Finished processing 953000 training data
# Finished processing 954000 training data
# Finished processing 955000 training data
# Finished processing 956000 training data
# Finished processing 957000 training data
# Finished processing 958000 training data
# Finished processing 959000 training data
# Finished processing 960000 training data
# Finished processing 961000 training data
# Finished processing 962000 training data
# Finished processing 963000 training data
# Finished processing 964000 training data
# Finished processing 965000 training data
# Finished processing 966000 training data
# Finished processing 967000 training data
# Finished processing 968000 training data
# Finished processing 969000 training data
# Finished processing 970000 training data
# Finished processing 971000 training data
# Finished processing 972000 training data
# Finished processing 973000 training data
# Finished processing 974000 training data
# Finished processing 975000 training data
# Finished processing 976000 training data
# Finished processing 977000 training data
# Finished processing 978000 training data
# Finished processing 979000 training data
# Finished processing 980000 training data
# Finished processing 981000 training data
# Finished processing 982000 training data
# Finished processing 983000 training data
# Finished processing 984000 training data
# Finished processing 985000 training data
# Finished processing 986000 training data
# Finished processing 987000 training data
# Finished processing 988000 training data
# Finished processing 989000 training data
# Finished processing 990000 training data
# Finished processing 991000 training data
# Finished processing 992000 training data
# Finished processing 993000 training data
# Finished processing 994000 training data
# Finished processing 995000 training data
# Finished processing 996000 training data
# Finished processing 997000 training data
# Finished processing 998000 training data
# Finished processing 999000 training data
# Finished processing 1000000 training data
# Finished processing 1001000 training data
# Finished processing 1002000 training data
# Finished processing 1003000 training data
# Finished processing 1004000 training data
# Finished processing 1005000 training data
# Finished processing 1006000 training data
# Finished processing 1007000 training data
# Finished processing 1008000 training data
# Finished processing 1009000 training data
# Finished processing 1010000 training data
# Finished processing 1011000 training data
# Finished processing 1012000 training data
# Finished processing 1013000 training data
# Finished processing 1014000 training data
# Finished processing 1015000 training data
# Finished processing 1016000 training data
# Finished processing 1017000 training data
# Finished processing 1018000 training data
# Finished processing 1019000 training data
# Finished processing 1020000 training data
# Finished processing 1021000 training data
# Finished processing 1022000 training data
# Finished processing 1023000 training data
# Finished processing 1024000 training data
# Finished processing 1025000 training data
# Finished processing 1026000 training data
# Finished processing 1027000 training data
# Finished processing 1028000 training data
# Finished processing 1029000 training data
# Finished processing 1030000 training data
# Finished processing 1031000 training data
# Finished processing 1032000 training data
# Finished processing 1033000 training data
# Finished processing 1034000 training data
# Finished processing 1035000 training data
# Finished processing 1036000 training data
# Finished processing 1037000 training data
# Finished processing 1038000 training data
# Finished processing 1039000 training data
# Finished processing 1040000 training data
# Finished processing 1041000 training data
# Finished processing 1042000 training data
# Finished processing 1043000 training data
# Finished processing 1044000 training data
# Finished processing 1045000 training data
# Finished processing 1046000 training data
# Finished processing 1047000 training data
# Finished processing 1048000 training data
# Finished processing 1049000 training data
# Finished processing 1050000 training data
# Finished processing 1051000 training data
# Finished processing 1052000 training data
# Finished processing 1053000 training data
# Finished processing 1054000 training data
# Finished processing 1055000 training data
# Finished processing 1056000 training data
# Finished processing 1057000 training data
# Finished processing 1058000 training data
# Finished processing 1059000 training data
# Finished processing 1060000 training data
# Finished processing 1061000 training data
# Finished processing 1062000 training data
# Finished processing 1063000 training data
# Finished processing 1064000 training data
# Finished processing 1065000 training data
# Finished processing 1066000 training data
# Finished processing 1067000 training data
# Finished processing 1068000 training data
# Finished processing 1069000 training data
# Finished processing 1070000 training data
# Finished processing 1071000 training data
# Finished processing 1072000 training data
# Finished processing 1073000 training data
# Finished processing 1074000 training data
# Finished processing 1075000 training data
# Finished processing 1076000 training data
# Finished processing 1077000 training data
# Finished processing 1078000 training data
# Finished processing 1079000 training data
# Finished processing 1080000 training data
# Finished processing 1081000 training data
# Finished processing 1082000 training data
# Finished processing 1083000 training data
# Finished processing 1084000 training data
# Finished processing 1085000 training data
# Finished processing 1086000 training data
# Finished processing 1087000 training data
# Finished processing 1088000 training data
# Finished processing 1089000 training data
# Finished processing 1090000 training data
# Finished processing 1091000 training data
# Finished processing 1092000 training data
# Finished processing 1093000 training data
# Finished processing 1094000 training data
# Finished processing 1095000 training data
# Finished processing 1096000 training data
# Finished processing 1097000 training data
# Finished processing 1098000 training data
# Finished processing 1099000 training data
# Finished processing 1100000 training data
# Finished processing 1101000 training data
# Finished processing 1102000 training data
# Finished processing 1103000 training data
# Finished processing 1104000 training data
# Finished processing 1105000 training data
# Finished processing 1106000 training data
# Finished processing 1107000 training data
# Finished processing 1108000 training data
# Finished processing 1109000 training data
# Finished processing 1110000 training data
# Finished processing 1111000 training data
# Finished processing 1112000 training data
# Finished processing 1113000 training data
# Finished processing 1114000 training data
# Finished processing 1115000 training data
# Finished processing 1116000 training data
# Finished processing 1117000 training data
# Finished processing 1118000 training data
# Finished processing 1119000 training data
# Finished processing 1120000 training data
# Finished processing 1121000 training data
# Finished processing 1122000 training data
# Finished processing 1123000 training data
# Finished processing 1124000 training data
# Finished processing 1125000 training data
# Finished processing 1126000 training data
# Finished processing 1127000 training data
# Finished processing 1128000 training data
# Finished processing 1129000 training data
# Finished processing 1130000 training data
# Finished processing 1131000 training data
# Finished processing 1132000 training data
# Finished processing 1133000 training data
# Finished processing 1134000 training data
# Finished processing 1135000 training data
# Finished processing 1136000 training data
# Finished processing 1137000 training data
# Finished processing 1138000 training data
# Finished processing 1139000 training data
# Finished processing 1140000 training data
# Finished processing 1141000 training data
# Finished processing 1142000 training data
# Finished processing 1143000 training data
# Finished processing 1144000 training data
# Finished processing 1145000 training data
# Finished processing 1146000 training data
# Finished processing 1147000 training data
# Finished processing 1148000 training data
# Finished processing 1149000 training data
# Finished processing 1150000 training data
# Finished processing 1151000 training data
# Finished processing 1152000 training data
# Finished processing 1153000 training data
# Finished processing 1154000 training data
# Finished processing 1155000 training data
# Finished processing 1156000 training data
# Finished processing 1157000 training data
# Finished processing 1158000 training data
# Finished processing 1159000 training data
# Finished processing 1160000 training data
# Finished processing 1161000 training data
# Finished processing 1162000 training data
# Finished processing 1163000 training data
# Finished processing 1164000 training data
# Finished processing 1165000 training data
# Finished processing 1166000 training data
# Finished processing 1167000 training data
# Finished processing 1168000 training data
# ...
# Finished processing 1220000 training data
# Finished processing 1221000 training data
# Finished processing 1222000 training data
# Finished processing 1223000 training data
# Finished processing 1224000 training data
# Finished processing 1225000 training data
# Finished processing 1226000 training data
# Finished processing 1227000 training data
# Finished processing 1228000 training data
# Finished processing 1229000 training data
# Finished processing 1230000 training data
# Finished processing 1231000 training data
# Finished processing 1232000 training data
# Finished processing 1233000 training data
# Finished processing 1234000 training data
# Finished processing 1235000 training data
# Finished processing 1236000 training data
# Finished processing 1237000 training data
# Finished processing 1238000 training data
# Finished processing 1239000 training data
# Finished processing 1240000 training data
# Finished processing 1241000 training data
# Finished processing 1242000 training data
# Finished processing 1243000 training data
# Finished processing 1244000 training data
# Finished processing 1245000 training data
# Finished processing 1246000 training data
# Finished processing 1247000 training data
# Finished processing 1248000 training data
# Finished processing 1249000 training data
# Finished processing 1250000 training data
# Finished processing 1251000 training data
# Finished processing 1252000 training data
# Finished processing 1253000 training data
# Finished processing 1254000 training data
# Finished processing 1255000 training data
# Finished processing 1256000 training data
# Finished processing 1257000 training data
# Finished processing 1258000 training data
# Finished processing 1259000 training data
# Finished processing 1260000 training data
# Finished processing 1261000 training data
# Finished processing 1262000 training data
# Finished processing 1263000 training data
# Finished processing 1264000 training data
# Finished processing 1265000 training data
# Finished processing 1266000 training data
# Finished processing 1267000 training data
# Finished processing 1268000 training data
# Finished processing 1269000 training data
# Finished processing 1270000 training data
# Finished processing 1271000 training data
# Finished processing 1272000 training data
# Finished processing 1273000 training data
# Finished processing 1274000 training data
# Finished processing 1275000 training data
# Finished processing 1276000 training data
# Finished processing 1277000 training data
# Finished processing 1278000 training data
# Finished processing 1279000 training data
# Finished processing 1280000 training data
# Finished processing 1281000 training data
# Finished processing 1282000 training data
# Finished processing 1283000 training data
# Finished processing 1284000 training data
# Finished processing 1285000 training data
# Finished processing 1286000 training data
# Finished processing 1287000 training data
# Finished processing 1288000 training data
# Finished processing 1289000 training data
# Finished processing 1290000 training data
# Finished processing 1291000 training data
# Finished processing 1292000 training data
# Finished processing 1293000 training data
# Finished processing 1294000 training data
# Finished processing 1295000 training data
# Finished processing 1296000 training data
# Finished processing 1297000 training data
# Finished processing 1298000 training data
# Finished processing 1299000 training data
# Finished processing 1300000 training data
# Finished processing 1301000 training data
# Finished processing 1302000 training data
# Finished processing 1303000 training data
# Finished processing 1304000 training data
# Finished processing 1305000 training data
# Finished processing 1306000 training data
# Finished processing 1307000 training data
# Finished processing 1308000 training data
# Finished processing 1309000 training data
# Finished processing 1310000 training data
# Finished processing 1311000 training data
# Finished processing 1312000 training data
# Finished processing 1313000 training data
# Finished processing 1314000 training data
# Finished processing 1315000 training data
# Finished processing 1316000 training data
# Finished processing 1317000 training data
# Finished processing 1318000 training data
# Finished processing 1319000 training data
# Finished processing 1320000 training data
# Finished processing 1321000 training data
# Finished processing 1322000 training data
# Finished processing 1323000 training data
# Finished processing 1324000 training data
# Finished processing 1325000 training data
# Finished processing 1326000 training data
# Finished processing 1327000 training data
# Finished processing 1328000 training data
# Finished processing 1329000 training data
# Finished processing 1330000 training data
# Finished processing 1331000 training data
# Finished processing 1332000 training data
# Finished processing 1333000 training data
# Finished processing 1334000 training data
# Finished processing 1335000 training data
# Finished processing 1336000 training data
# Finished processing 1337000 training data
# Finished processing 1338000 training data
# Finished processing 1339000 training data
# Finished processing 1340000 training data
# Finished processing 1341000 training data
# Finished processing 1342000 training data
# Finished processing 1343000 training data
# Finished processing 1344000 training data
# Finished processing 1345000 training data
# Finished processing 1346000 training data
# Finished processing 1347000 training data
# Finished processing 1348000 training data
# Finished processing 1349000 training data
# Finished processing 1350000 training data
# Finished processing 1351000 training data
# Finished processing 1352000 training data
# Finished processing 1353000 training data
# Finished processing 1354000 training data
# Finished processing 1355000 training data
# Finished processing 1356000 training data
# Finished processing 1357000 training data
# Finished processing 1358000 training data
# Finished processing 1359000 training data
# Finished processing 1360000 training data
# Finished processing 1361000 training data
# Finished processing 1362000 training data
# Finished processing 1363000 training data
# Finished processing 1364000 training data
# Finished processing 1365000 training data
# Finished processing 1366000 training data
# Finished processing 1367000 training data
# Finished processing 1368000 training data
# Finished processing 1369000 training data
# Finished processing 1370000 training data
# Finished processing 1371000 training data
# Finished processing 1372000 training data
# Finished processing 1373000 training data
# Finished processing 1374000 training data
# Finished processing 1375000 training data
# Finished processing 1376000 training data
# Finished processing 1377000 training data
# Finished processing 1378000 training data
# Finished processing 1379000 training data
# Finished processing 1380000 training data
# Finished processing 1381000 training data
# Finished processing 1382000 training data
# Finished processing 1383000 training data
# Finished processing 1384000 training data
# Finished processing 1385000 training data
# Finished processing 1386000 training data
# Finished processing 1387000 training data
# Finished processing 1388000 training data
# Finished processing 1389000 training data
# Finished processing 1390000 training data
# Finished processing 1391000 training data
# Finished processing 1392000 training data
# Finished processing 1393000 training data
# Finished processing 1394000 training data
# Finished processing 1395000 training data
# Finished processing 1396000 training data
# Finished processing 1397000 training data
# Finished processing 1398000 training data
# Finished processing 1399000 training data
# Finished processing 1400000 training data
# Finished processing 1401000 training data
# Finished processing 1402000 training data
# Finished processing 1403000 training data
# Finished processing 1404000 training data
# Finished processing 1405000 training data
# Finished processing 1406000 training data
# Finished processing 1407000 training data
# Finished processing 1408000 training data
# Finished processing 1409000 training data
# Finished processing 1410000 training data
# Finished processing 1411000 training data
# Finished processing 1412000 training data
# Finished processing 1413000 training data
# Finished processing 1414000 training data
# Finished processing 1415000 training data
# Finished processing 1416000 training data
# Finished processing 1417000 training data
# Finished processing 1418000 training data
# Finished processing 1419000 training data
# Finished processing 1420000 training data
# Finished processing 1421000 training data
# Finished processing 1422000 training data
# Finished processing 1423000 training data
# Finished processing 1424000 training data
# Finished processing 1425000 training data
# Finished processing 1426000 training data
# Finished processing 1427000 training data
# Finished processing 1428000 training data
# Finished processing 1429000 training data
# Finished processing 1430000 training data
# Finished processing 1431000 training data
# Finished processing 1432000 training data
# Finished processing 1433000 training data
# Finished processing 1434000 training data
# Finished processing 1435000 training data
# Finished processing 1436000 training data
# Finished processing 1437000 training data
# Finished processing 1438000 training data
# Finished processing 1439000 training data
# Finished processing 1440000 training data
# Finished processing 1441000 training data
# Finished processing 1442000 training data
# Finished processing 1443000 training data
# Finished processing 1444000 training data
# Finished processing 1445000 training data
# Finished processing 1446000 training data
# Finished processing 1447000 training data
# Finished processing 1448000 training data
# Finished processing 1449000 training data
# Finished processing 1450000 training data
# Finished processing 1451000 training data
# Finished processing 1452000 training data
# Finished processing 1453000 training data
# Finished processing 1454000 training data
# Finished processing 1455000 training data
# Finished processing 1456000 training data
# Finished processing 1457000 training data
# Finished processing 1458000 training data
# Finished processing 1459000 training data
# Finished processing 1460000 training data
# Finished processing 1461000 training data
# Finished processing 1462000 training data
# Finished processing 1463000 training data
# Finished processing 1464000 training data
# Finished processing 1465000 training data
# Finished processing 1466000 training data
# Finished processing 1467000 training data
# Finished processing 1468000 training data
# Finished processing 1469000 training data
# Finished processing 1470000 training data
# Finished processing 1471000 training data
# Finished processing 1472000 training data
# Finished processing 1473000 training data
# Finished processing 1474000 training data
# Finished processing 1475000 training data
# Finished processing 1476000 training data
# Finished processing 1477000 training data
# Finished processing 1478000 training data
# Finished processing 1479000 training data
# Finished processing 1480000 training data
# Finished processing 1481000 training data
# Finished processing 1482000 training data
# Finished processing 1483000 training data
# Finished processing 1484000 training data
# Finished processing 1485000 training data
# Finished processing 1486000 training data
# Finished processing 1487000 training data
# Finished processing 1488000 training data
# Finished processing 1489000 training data
# Finished processing 1490000 training data
# Finished processing 1491000 training data
# Finished processing 1492000 training data
# Finished processing 1493000 training data
# Finished processing 1494000 training data
# Finished processing 1495000 training data
# Finished processing 1496000 training data
# Finished processing 1497000 training data
# Finished processing 1498000 training data
# Finished processing 1499000 training data
# Finished processing 1500000 training data
# Finished processing 1501000 training data
# Finished processing 1502000 training data
# Finished processing 1503000 training data
# Finished processing 1504000 training data
# Finished processing 1505000 training data
# Finished processing 1506000 training data
# Finished processing 1507000 training data
# Finished processing 1508000 training data
# Finished processing 1509000 training data
# Finished processing 1510000 training data
# Finished processing 1511000 training data
# Finished processing 1512000 training data
# Finished processing 1513000 training data
# Finished processing 1514000 training data
# Finished processing 1515000 training data
# Finished processing 1516000 training data
# Finished processing 1517000 training data
# Finished processing 1518000 training data
# Finished processing 1519000 training data
# Finished processing 1520000 training data
# Finished processing 1521000 training data
# Finished processing 1522000 training data
# Finished processing 1523000 training data
# Finished processing 1524000 training data
# Finished processing 1525000 training data
# Finished processing 1526000 training data
# Finished processing 1527000 training data
# Finished processing 1528000 training data
# Finished processing 1529000 training data
# Finished processing 1530000 training data
# Finished processing 1531000 training data
# Finished processing 1532000 training data
# Finished processing 1533000 training data
# Finished processing 1534000 training data
# Finished processing 1535000 training data
# Finished processing 1536000 training data
# Finished processing 1537000 training data
# Finished processing 1538000 training data
# Finished processing 1539000 training data
# Finished processing 1540000 training data
# Finished processing 1541000 training data
# Finished processing 1542000 training data
# Finished processing 1543000 training data
# Finished processing 1544000 training data
# Finished processing 1545000 training data
# Finished processing 1546000 training data
# Finished processing 1547000 training data
# Finished processing 1548000 training data
# Finished processing 1549000 training data
# Finished processing 1550000 training data
# Finished processing 1551000 training data
# Finished processing 1552000 training data
# Finished processing 1553000 training data
# Finished processing 1554000 training data
# Finished processing 1555000 training data
# Finished processing 1556000 training data
# Finished processing 1557000 training data
# Finished processing 1558000 training data
# Finished processing 1559000 training data
# Finished processing 1560000 training data
# Finished processing 1561000 training data
# Finished processing 1562000 training data
# Finished processing 1563000 training data
# Finished processing 1564000 training data
# Finished processing 1565000 training data
# Finished processing 1566000 training data
# Finished processing 1567000 training data
# Finished processing 1568000 training data
# Finished processing 1569000 training data
# Finished processing 1570000 training data
# Finished processing 1571000 training data
# Finished processing 1572000 training data
# Finished processing 1573000 training data
# Finished processing 1574000 training data
# Finished processing 1575000 training data
# Finished processing 1576000 training data
# Finished processing 1577000 training data
# Finished processing 1578000 training data
# Finished processing 1579000 training data
# Finished processing 1580000 training data
# Finished processing 1581000 training data
# Finished processing 1582000 training data
# Finished processing 1583000 training data
# Finished processing 1584000 training data
# Finished processing 1585000 training data
# Finished processing 1586000 training data
# Finished processing 1587000 training data
# Finished processing 1588000 training data
# Finished processing 1589000 training data
# Finished processing 1590000 training data
# Finished processing 1591000 training data
# Finished processing 1592000 training data
# Finished processing 1593000 training data
# Finished processing 1594000 training data
# Finished processing 1595000 training data
# Finished processing 1596000 training data
# Finished processing 1597000 training data
# Finished processing 1598000 training data
# Finished processing 1599000 training data

# %%
df.to_csv('train.csv', index=False)
max_length
# Out:
# 116

# %%
X_train = [preprocess(text) for text in X_train]
X_val = [preprocess(text) for text in X_val]
X_test = [preprocess(text) for text in X_test]

print("There are {} train set".format(len(X_train)))
print("There are {} validation set".format(len(X_val)))
print("There are {} test set".format(len(X_test)))
# Out:
# There are 1440000 train set
# There are 160000 validation set
# There are 498 test set

# %%
import torch
import apex
from pytorch_pretrained_bert.tokenization import BertTokenizer
from fast_bert.data import BertDataBunch
from fast_bert.learner import BertLearner
from fast_bert.metrics import accuracy
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-7370ab98fab1> in <module>
#       1 import torch
# ----> 2 import apex
#       3 from pytorch_pretrained_bert.tokenization import BertTokenizer
#       4 from fast_bert.data import BertDataBunch
#       5 from fast_bert.learner import BertLearner
#
# /usr/local/lib/python3.7/site-packages/apex/__init__.py in <module>
#      16 from apex.exceptions import (ApexAuthSecret,
#      17                              ApexSessionSecret)
# ---> 18 from apex.interfaces import (ApexImplementation,
#      19                              IApex)
#      20 from apex.lib.libapex import (groupfinder,
#
# /usr/local/lib/python3.7/site-packages/apex/interfaces.py in <module>
#       8     pass
#       9
# ---> 10 class ApexImplementation(object):
#      11     """ Class so that we can tell if Apex is installed from other
#      12     applications
#
# /usr/local/lib/python3.7/site-packages/apex/interfaces.py in ApexImplementation()
#      12     applications
#      13     """
# ---> 14     implements(IApex)
#
# /usr/local/lib/python3.7/site-packages/zope/interface/declarations.py in implements(*interfaces)
#     481     # the coverage for this block there. :(
#     482     if PYTHON3:
# --> 483         raise TypeError(_ADVICE_ERROR % 'implementer')
#     484     _implements("implements", interfaces, classImplements)
#     485
#
# TypeError: Class advice impossible in Python3.  Use the @implementer class decorator instead.
